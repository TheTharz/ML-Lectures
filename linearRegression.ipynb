# %% [markdown]
# # Implementing linear regression algorithm

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_csv('data.csv')
print(data)
# Out:
#      SAT   GPA
# 0   1714  2.40
# 1   1664  2.52
# 2   1760  2.54
# 3   1685  2.74
# 4   1693  2.83
# ..   ...   ...
# 79  1936  3.71
# 80  1810  3.71
# 81  1987  3.73
# 82  1962  3.76
# 83  2050  3.81
#
# [84 rows x 2 columns]

# %%
plt.scatter(data.SAT,data.GPA)
plt.show()

# %%
def loss_function(m,b,points):
  total_error = 0;
  for i in range(0,len(points)):
    x = points.iloc[i].SAT
    y = points.iloc[i].GPA
    total_error += (y - (m*x + b))**2
  total_error/=float(len(points))

# %%
def gradient_descent(m_now,b_now,points,l):
  m_gradient = 0
  b_gradient = 0

  n = len(points)
  for i in range(0,n):
    x = points.iloc[i].SAT
    y = points.iloc[i].GPA

    m_gradient += -(2/n)*x*(y-(m_now*x + b_now))
    b_gradient += -(2/n)*(y-(m_now*x + b_now))

  m = m_now - m_gradient*l
  b = b_now - b_gradient*l

  return m,b

# %%
m = 0.001
b = 0.001
l = 0.00001
epochs = 250

for i in range(epochs):
  m,b = gradient_descent(m,b,data,l)

print(m,b)

plt.scatter(data.SAT,data.GPA,color="red")
plt.plot(list(range(0,2400)),[m*x + b for x in range(0,2400)],color="black")
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_20164\411763213.py:10: RuntimeWarning: overflow encountered in double_scalars
#   m_gradient += -(2/n)*x*(y-(m_now*x + b_now))
# C:\Users\DELL\AppData\Local\Temp\ipykernel_20164\411763213.py:13: RuntimeWarning: invalid value encountered in double_scalars
#   m = m_now - m_gradient*l
# nan nan
